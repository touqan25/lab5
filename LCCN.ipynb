# %%
import requests
import json
import os

# %% [markdown]
# # Defining the URI

# %%
base_uri = "https://loc.gov"
lccn_uri = "https://lccn.loc.gov/"

item_info_list = [
    "/resource/cph.3f05183/",
    "/resource/fsa.8d24709/",
    "/resource/highsm.64003/"
]

lccn_dict = {}

# %% [markdown]
# # Requesting an Item and its Metadata from LOC

# %%
parameters = {'fo':'json'}

# %%
output_dir = 'json_responses'
os.makedirs(output_dir, exist_ok=True)

# %%
for uri in item_info_list:
    response = requests.get(base_uri + uri, params=parameters)
    print(f"\nRequesting {response.url}")

    if response.status_code == 200:
        data = response.json()
        if "item" in data and 'library_of_congress_control_number' in data["item"]:
            lccn = data["item"]['library_of_congress_control_number']
            lccn_dict[uri] = lccn
            print(f"{uri} : {lccn}")
            permalink = lccn_uri + '/' + lccn
            print(f"Permalink : {permalink}")
            print(f"JSON response : {response.json()}")
            filename = os.path.join(output_dir, f"{lccn}.json")
            with open(filename, 'w') as f:
                json.dump(data, f, indent=4)
            print(f"Saved JSON response to {filename}")
        else:
            print(f"{uri} : No LCCN found")
    else:
        print(f"Error: {response.status_code}")
# Out:
# Requesting https://www.loc.gov/resource/cph.3f05183/?fo=json
# /resource/cph.3f05183/ : 98508155
# Permalink : https://lccn.loc.gov//98508155
# JSON response : {'articles_and_essays': None, 'cite_this': {'apa': 'Federal Art Project, S. <cite>For Greater Knowledge on More Subjects Use Your Library More Often</cite>. Illinois Chicago, None. [Chicago: illinois wpa art project, between 1936 and 1941] [Photograph] Retrieved from the Library of Congress, https://www.loc.gov/item/98508155/.', 'chicago': 'Federal Art Project, Sponsor. <cite>For Greater Knowledge on More Subjects Use Your Library More Often</cite>. Illinois Chicago, None. [Chicago: illinois wpa art project, between 1936 and 1941] Photograph. https://www.loc.gov/item/98508155/.', 'mla': 'Federal Art Project, Sponsor. <cite>For Greater Knowledge on More Subjects Use Your Library More Often</cite>. [Chicago: illinois wpa art project, between 1936 and 1941] Photograph. Retrieved from the Library of Congress, &lt;www.loc.gov/item/98508155/&gt;.'}, 'item': {'_version_': 1754109026683060224, 'access_restricted': False, 'aka': ['https://www.loc.gov/pictures/item/98508155/', 'http://www.loc.gov/item/98508155/', 'http://www.loc.gov/pictures/item/98508155/', 'https://www.loc.gov/pictures/collection/wpapos/item/98508155/', 'http://www.loc.gov/pictures/collection/wpapos/item/98508155/', 'http://www.loc.gov/resource/cph.3f05183/', 'http://lccn.loc.gov/98508155', 'https://hdl.loc.gov/loc.pnp/cph.3f05183'], 'call_number': 'POS - WPA - ILL .01 .F665, no. 1 (B size) [P&P]', 'campaigns': [], 'contributor_names': ['Federal Art Project, sponsor'], 'contributors': [{'federal art project': 'https://www.loc.gov/search/?fa=contributor:federal+art+project&fo=json'}], 'control_number': '', 'created': '2022-08-30T06:05:30Z', 'created_published': ['Chicago : Illinois WPA Art Project, [between 1936 and 1941]'], 'created_published_date': '[between 1936 and 1941]', 'date': '1936-01-01', 'dates': [{'1936': 'https://www.loc.gov/search/?dates=1936/1936&fo=json'}], 'description': ['1 print on board (poster) : silkscreen, color. | Poster showing a mortarboard and a pair of glasses superimposed over a globe, promoting use of libraries.'], 'digital_id': ['cph 3f05183 //hdl.loc.gov/loc.pnp/cph.3f05183'], 'digitized': True, 'display_offsite': True, 'extract_timestamp': '2022-09-03T12:25:49.213Z', 'extract_urls': ['http://www.loc.gov/pictures/collection/wpapos/item/98508155/#wpapos', 'http://lccn.loc.gov/98508155#catalog-split-09'], 'format': [{'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}], 'format_headings': ['Posters--1930-1950.', 'Screen prints--Color--1930-1950.'], 'genre': ['Posters--1930-1950', 'Screen prints--Color--1930-1950'], 'group': ['wpapos', 'catalog-split-09', 'catalog', 'wpa-posters', 'main-catalog-split-09', 'main-catalog'], 'hassegments': False, 'id': 'http://www.loc.gov/item/98508155/', 'image_url': ['https://tile.loc.gov/storage-services/service/pnp/cph/3f00000/3f05000/3f05100/3f05183_150px.jpg#h=150&w=103', 'https://tile.loc.gov/storage-services/service/pnp/cph/3f00000/3f05000/3f05100/3f05183t.gif#h=150&w=103', 'https://tile.loc.gov/storage-services/service/pnp/cph/3f00000/3f05000/3f05100/3f05183r.jpg#h=640&w=440', 'https://tile.loc.gov/storage-services/service/pnp/cph/3f00000/3f05000/3f05100/3f05183v.jpg#h=1024&w=705'], 'index': 1, 'item': {'call_number': 'POS - WPA - ILL .01 .F665, no. 1 (B size) [P&P]', 'contributor_names': ['Federal Art Project, sponsor '], 'contributors': ['Federal Art Project, sponsor'], 'control_number': '98508155', 'created': '2022-08-30T06:05:30Z', 'created_published': 'Chicago : Illinois WPA Art Project, [between 1936 and 1941]', 'created_published_date': '[between 1936 and 1941]', 'creators': [{'link': 'https://www.loc.gov/pictures/related/?fi=name&q=Federal%20Art%20Project&co=wpapos', 'role': 'sponsor', 'title': 'Federal Art Project'}], 'date': '[between 1936 and 1941]', 'digital_id': ['cph 3f05183 //hdl.loc.gov/loc.pnp/cph.3f05183'], 'display_offsite': True, 'format': ['still image'], 'formats': [{'link': 'https://www.loc.gov/pictures/related ...
# Saved JSON response to json_responses\98508155.json
#
# Requesting https://www.loc.gov/resource/fsa.8d24709/?fo=json
# /resource/fsa.8d24709/ : 2017843202
# Permalink : https://lccn.loc.gov//2017843202
# JSON response : {'articles_and_essays': None, 'cite_this': {'apa': 'Parks, G., photographer. (1943) <cite>Daytona Beach, Florida. Bethune-Cookman College. Students in the library reading room</cite>. Daytona Beach Volusia County Florida United States, 1943. Jan. [Photograph] Retrieved from the Library of Congress, https://www.loc.gov/item/2017843202/.', 'chicago': 'Parks, Gordon, photographer. <cite>Daytona Beach, Florida. Bethune-Cookman College. Students in the library reading room</cite>. Daytona Beach Volusia County Florida United States, 1943. Jan. Photograph. https://www.loc.gov/item/2017843202/.', 'mla': 'Parks, Gordon, photographer. <cite>Daytona Beach, Florida. Bethune-Cookman College. Students in the library reading room</cite>. Jan. Photograph. Retrieved from the Library of Congress, &lt;www.loc.gov/item/2017843202/&gt;.'}, 'item': {'_version_': 1731151525508546560, 'access_restricted': False, 'aka': ['http://www.loc.gov/pictures/collection/fsa/item/2017843202/', 'http://www.loc.gov/item/2017843202/', 'http://www.loc.gov/pictures/item/2017843202/', 'https://hdl.loc.gov/loc.pnp/fsa.8d24709', 'http://www.loc.gov/resource/fsa.8d24709/', 'http://lccn.loc.gov/2017843202'], 'call_number': 'LC-USW3- 014835-E [P&P] LOT 682 (corresponding photographic print)', 'campaigns': [], 'contributor_names': ['Parks, Gordon, 1912-2006, photographer'], 'contributors': [{'parks, gordon': 'https://www.loc.gov/search/?fa=contributor:parks,+gordon&fo=json'}], 'control_number': '', 'created': '2017-09-26T03:37:57Z', 'created_published': ['1943 Jan.'], 'created_published_date': '1943 Jan.', 'date': '1943-01-01', 'dates': [{'1943': 'https://www.loc.gov/search/?dates=1943/1943&fo=json'}], 'description': ['1 negative : nitrate ; 2 1/4 x 2 1/4 inches or smaller.'], 'digital_id': ['fsa 8d24709 //hdl.loc.gov/loc.pnp/fsa.8d24709'], 'digitized': True, 'display_offsite': True, 'extract_timestamp': '2021-09-01T20:20:28.197Z', 'extract_urls': ['http://www.loc.gov/pictures/collection/fsa/item/2017843202/#fsa', 'http://lccn.loc.gov/2017843202#catalog-split-13'], 'format': [{'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}], 'format_headings': ['Nitrate negatives.'], 'genre': ['Nitrate negatives'], 'group': ['fsa', 'catalog-split-13', 'catalog', 'fsa-owi-black-and-white-negatives', 'main-catalog-split-13', 'main-catalog'], 'hassegments': False, 'id': 'http://www.loc.gov/item/2017843202/', 'image_url': ['https://tile.loc.gov/storage-services/service/pnp/fsa/8d24000/8d24700/8d24709_150px.jpg#h=150&w=143', 'https://tile.loc.gov/storage-services/service/pnp/fsa/8d24000/8d24700/8d24709t.gif#h=150&w=149', 'https://tile.loc.gov/storage-services/service/pnp/fsa/8d24000/8d24700/8d24709r.jpg#h=640&w=610', 'https://tile.loc.gov/storage-services/service/pnp/fsa/8d24000/8d24700/8d24709v.jpg#h=1024&w=976'], 'index': 1, 'item': {'call_number': 'LC-USW3- 014835-E [P&P] LOT 682 (corresponding photographic print)', 'contributors': ['Parks, Gordon, 1912-2006, photographer.'], 'control_number': '2017843202', 'created': '2017-09-26T03:37:57Z', 'created_published': '1943 Jan.', 'created_published_date': '1943 Jan.', 'creators': [{'link': '//www.loc.gov/pictures/related/?fi=name&q=Parks%2C%20Gordon%2C%201912-2006&co=fsa', 'role': 'photographer', 'title': 'Parks, Gordon, 1912-2006'}], 'date': '1943 Jan.', 'digital_id': ['fsa 8d24709 //hdl.loc.gov/loc.pnp/fsa.8d24709'], 'display_offsite': True, 'format': ['still image'], 'formats': [{'link': '//www.loc.gov/pictures/related/?fi=format&q=Nitrate%20negatives.&co=fsa', 'title': 'Nitrate negatives.'}], 'genre': ['Nitrate negatives'], 'id': '2017843202', 'language': ['eng'], 'link': '//www.loc.gov/pictures/item/2017843202/', 'marc': '//www.loc.gov/pictures/item/2017843202/marc/', 'medium': ['1 negative : nitrate ; 2 1/4 x 2 1/4 inches or smaller.'], 'medium_brief': '1 negative :', 'mediums': ['1 negative : nitrate ; 2 1/4 x 2 1/4 inches or smaller.'], 'modified': '2017-09-26T03:37: ...
# Saved JSON response to json_responses\2017843202.json
#
# Requesting https://www.loc.gov/resource/highsm.64003/?fo=json
# /resource/highsm.64003/ : 2020722343
# Permalink : https://lccn.loc.gov//2020722343
# JSON response : {'articles_and_essays': None, 'cite_this': {'apa': 'Highsmith, C. M., photographer. (2020) <cite>An appropriately decorated "Bookmobile" bus belonging to the Perry County Public Library in Hazard, a coal town of 4,500 or so population in the hills of southeastern Kentucky</cite>. Hazard Perry County United States Kentucky, 2020. -07-19. [Photograph] Retrieved from the Library of Congress, https://www.loc.gov/item/2020722343/.', 'chicago': 'Highsmith, Carol M, photographer. <cite>An appropriately decorated "Bookmobile" bus belonging to the Perry County Public Library in Hazard, a coal town of 4,500 or so population in the hills of southeastern Kentucky</cite>. Hazard Perry County United States Kentucky, 2020. -07-19. Photograph. https://www.loc.gov/item/2020722343/.', 'mla': 'Highsmith, Carol M, photographer. <cite>An appropriately decorated "Bookmobile" bus belonging to the Perry County Public Library in Hazard, a coal town of 4,500 or so population in the hills of southeastern Kentucky</cite>. -07-19. Photograph. Retrieved from the Library of Congress, &lt;www.loc.gov/item/2020722343/&gt;.'}, 'item': {'_version_': 1730914868142276608, 'access_restricted': False, 'aka': ['https://www.loc.gov/pictures/item/2020722343/', 'http://www.loc.gov/item/2020722343/', 'http://www.loc.gov/pictures/item/2020722343/', 'https://www.loc.gov/pictures/collection/highsm/item/2020722343/', 'http://www.loc.gov/pictures/collection/highsm/item/2020722343/', 'https://hdl.loc.gov/loc.pnp/highsm.64003', 'https://hdl.loc.gov/loc.pnp/highsm.64003', 'http://www.loc.gov/resource/highsm.64003/', 'http://lccn.loc.gov/2020722343'], 'call_number': 'LC-DIG-highsm- 64003 (ONLINE) [P&P]', 'campaigns': [], 'contributor_names': ['Highsmith, Carol M., 1946-, photographer'], 'contributors': [{'highsmith, carol m.': 'https://www.loc.gov/search/?fa=contributor:highsmith,+carol+m.&fo=json'}], 'control_number': '', 'created': '2020-12-01T07:00:24Z', 'created_published': ['2020-07-19.'], 'created_published_date': '2020-07-19.', 'date': '2020-01-01', 'dates': [{'2020': 'https://www.loc.gov/search/?dates=2020/2020&fo=json'}], 'description': ['1 photograph : digital, tiff file, color.'], 'digital_id': ['highsm 64003 https://hdl.loc.gov/loc.pnp/highsm.64003'], 'digitized': True, 'display_offsite': True, 'extract_timestamp': '2021-08-31T05:27:20.532Z', 'extract_urls': ['http://www.loc.gov/pictures/collection/highsm/item/2020722343/#highsm', 'http://lccn.loc.gov/2020722343#catalog-split-09'], 'format': [{'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}], 'format_headings': ['Digital photographs--Color--2020.'], 'genre': ['Digital photographs--Color--2020'], 'group': ['highsm', 'catalog-split-09', 'catalog', 'carol-m-highsmith', 'main-catalog-split-09', 'main-catalog'], 'hassegments': False, 'id': 'http://www.loc.gov/item/2020722343/', 'image_url': ['https://tile.loc.gov/storage-services/service/pnp/highsm/64000/64003_150px.jpg#h=113&w=150', 'https://tile.loc.gov/storage-services/service/pnp/highsm/64000/64003r.jpg#h=480&w=640', 'https://tile.loc.gov/storage-services/service/pnp/highsm/64000/64003v.jpg#h=768&w=1024'], 'index': 1, 'item': {'call_number': 'LC-DIG-highsm- 64003 (ONLINE) [P&P]', 'contributors': ['Highsmith, Carol M., 1946- photographer.'], 'control_number': '2020722343', 'created': '2020-12-01T07:00:24Z', 'created_published': '2020-07-19.', 'created_published_date': '2020-07-19.', 'creators': [{'link': 'https://www.loc.gov/pictures/related/?fi=name&q=Highsmith%2C%20Carol%20M.%2C%201946-&co=highsm', 'role': 'photographer', 'title': 'Highsmith, Carol M., 1946-'}], 'date': '2020-07-19.', 'digital_id': ['highsm 64003 https://hdl.loc.gov/loc.pnp/highsm.64003'], 'display_offsite': True, 'format': ['still image'], 'formats': [{'link': 'https://www.loc.gov/pictures/related/?fi=format&q=Digital%20photographs--Color--2020.&co=highsm', 'title': 'Digital photographs--Color--2020.'}], 'genre': ['Digital phot ...
# Saved JSON response to json_responses\2020722343.json

# %% [markdown]
# # Using a Different Parameter

# %%
def search_loc(query):
    parameters = {'q': query, 'fo': 'json'}
    response = requests.get(base_uri, params=parameters)
    print(f"\nRequesting {response.url}")

    if response.status_code == 200:
        data = response.json()
        print(json.dumps(data, indent=4))
    else:
        print(f"Error: {response.status_code}")

def main():
    query = input("Enter a search term: ")
    search_loc(query)

if __name__ == "__main__":
    main()
# Out:
# Requesting https://www.loc.gov/?fo=json&q=lincoln
# {
#     "_featured_events": [
#         {
#             "category": "Concert",
#             "day": 30,
#             "link": "/item/event-398220/",
#             "month": "Jan",
#             "time": "8:00 p.m. - 10:00 p.m.",
#             "title": "Dunedin Consort"
#         },
#         {
#             "category": "Concert",
#             "day": 31,
#             "link": "/item/event-398223/",
#             "month": "Jan",
#             "time": "8:00 p.m. - 10:00 p.m.",
#             "title": "Asko|Sch\u00f6nberg Ensemble Concert I"
#         },
#         {
#             "category": "Lecture",
#             "day": 5,
#             "link": "/item/event-397800/",
#             "month": "Feb",
#             "time": "11:00 a.m. - Noon",
#             "title": "Gallery Talk: Rosa Parks, Before the Bus"
#         }
#     ],
#     "_featured_exhibits": [
#         {
#             "dates": "Through September 2020",
#             "link": "/exhibitions/rosa-parks-in-her-own-words/about-this-exhibition/",
#             "thumb": "/static/home/images/your-library/exhibitions/Rosa=Parks-Terek-Portrait-130x84.jpg",
#             "title": "Rosa Parks: In Her Own Words"
#         },
#         {
#             "dates": "Through September 2020",
#             "link": "/exhibitions/women-fight-for-the-vote/about-this-exhibition/",
#             "thumb": "/static/home/images/your-library/exhibitions/exhibitions-women-suffrage.jpg",
#             "title": "Shall Not Be Denied: Women Fight for the Vote"
#         },
#         {
#             "dates": "Through September 2020",
#             "link": "/exhibitions/comic-art/about-this-exhibition/",
#             "thumb": "/static/home/images/your-library/exhibitions/comic-art.jpg",
#             "title": "Comic Art: 120 Years of Panels and Pages"
#         }
#     ],
#     "_featured_item": {
#         "image_mobile": "/static/home/images/trending/featured/ice-skating2_480x309.jpg",
#         "image_tablet": "/static/home/images/trending/featured/ice-skating2_750x483.jpg",
#         "link": "/item/2016712624/",
#         "portal": "Featured Item",
#         "title": "Ice Skating, ca. 1873-1916"
#     },
#     "_featured_news": [
#         {
#             "date": "December 18, 2019",
#             "link": "/item/prn-19-121/",
#             "title": "Librarian of Congress Appoints Maria Strong as Acting Register of Copyrights"
#         },
#         {
#             "date": "December 18, 2019",
#             "link": "/item/prn-19-120/",
#             "title": "New Endowment to Support National Library Service for the Blind and Print Disabled"
#         },
#         {
#             "date": "December 16, 2019",
#             "link": "/item/prn-19-119/",
#             "title": "Library Opens Nominations for Outstanding Federal Libraries, Librarians and Library Technicians"
#         },
#         {
#             "date": "December 12, 2019",
#             "link": "/item/prn-19-118/",
#             "title": "Library of Congress Opens Applications for Librarians-in-Residence Program"
#         }
#     ],
#     "_featured_video_banner": {
#         "caption": "2024 National Book Festival Main Stage",
#         "description": "Watch programs from the Main Stage live on Aug. 24 from 9:30 a.m. to 7:40 p.m., including: James Patterson, James McBride, Doris Kearns Goodwin, Max Greenfield, Sandra Cisneros, Abby Jimenez and Casey McQuiston, Tamron Hall and Lish Steiling, James S.A. Corey, and Rebecca Yarros.",
#         "link": "https://www.youtube.com/watch?v=IKbscwQ9lQY",
#         "media_url": "https://www.youtube-nocookie.com/embed/IKbscwQ9lQY",
#         "portal": "National Book Festival",
#         "position": "top",
#         "title": "Watch LIVE: National Book Festival Main Stage"
#     },
#     "_notice": "Public spaces and exhibitions in the Library's Jefferson building will be open to visitors on the federal holiday on Monday, Oct. 14. <a href=\"https://www.loc.gov/item/prn-24-a10/\">More</a> ...",
#     "breadcrumbs": [
#         {
#             "Home | Library of Congress": "https://www.loc.gov"
#         }
#     ],
#     "featured_content": [
#         {
#             "alt": "Collage of several different veterans in and out of uniform and of different races and genders",
#             "banner": "/static/home/images/featured/programs/vhp20_1200x560.jpg",
#             "description": "Honor a veteran by helping the Library collect their important stories.",
#             "link": "/programs/veterans-history-project/about-this-program/",
#             "title": "Veterans History Project"
#         },
#         {
#             "alt": "Children wearing typical dresses for Ecuadorian National Day. Corona Plaza, Queens NY, 2021. Photo by Camilo J. Vergara",
#             "banner": "/static/home/images/featured/heritage/hispheritage2022_1200x560.jpg",
#             "description": "U.S. cultural institutions pay tribute to generations of Hispanic Americans who have enriched our nation.",
#             "link": "https://www.hispanicheritagemonth.gov/",
#             "title": "National Hispanic Heritage Month"
#         },
#         {
#             "alt": "Image of Eddie Palmieri, a smiling man in a suit and holding a cigar, sitting at a Yamaha piano",
#             "banner": "/static/home/images/featured/programs/2024concerts-oct-eddie-palmier_1200x560.jpg",
#             "description": "Celebrate 100 years of performing arts and music at the Library.",
#             "link": "https://newsroom.loc.gov/news/library-of-congress-announces-fall-2024-concert-series/s/8df5fa69-0471-4633-8bcf-c5dce4293ba6",
#             "title": "Concerts from the Library"
#         },
#         {
#             "alt": "A view of the Great Hall of the Thomas Jefferson Building of the Library of Congress, with many people shown enjoying the beautiful architecture in the hall, on the stairs and in the gallery above",
#             "banner": "/static/home/images/featured/programs/live24-1200x560.jpg",
#             "description": "'Live! at the Library' features evening engagement in a gorgeous setting.",
#             "link": "/live/",
#             "title": "Thursday Night Fun & Programs"
#         },
#         {
#             "alt": "image of a sweatshirt, a book, a charm, a decorative pin, and a cup and saucer set from the Library's catalog",
#             "banner": "/static/home/images/featured/evergreen/2024-shop_1200x560.jpg",
#             "description": "Shop a vast selection of Library-themed gifts and apparel.",
#             "link": "https://library-of-congress-shop.myshopify.com/",
#             "title": "Library of Congress Store",
#             "type": "external"
#         }
#     ],
#     "featured_item": {
#         "caption": "",
#         "image": "/static/home/images/trending/video-screenshots/vhp_640x360.jpg",
#         "link": "/programs/veterans-history-project/about-this-program/",
#         "media_url": "https://stream-media.loc.gov/webcasts/2024/24-041vhp0000_LIBR0009000H_25th_Anniversary_English/24-041vhp0000_LIBR0009000H_25th_Anniversary_English-1920x1080_6000.mp4",
#         "portal": "Watch",
#         "title": "Veterans History Project: Share & Preserve the Stories of Veterans",
#         "type": "video"
#     },
#     "featured_public_domain": {
#         "abstract": "<p style=\"color: #fff\">Whether you ramble or run, stroll or stride, use a cane or a crutch, you'll find images of interest. Unless otherwise noted, the images are from the Prints & Photographs Division.</p> <p style=\"color: #fff\">Browse more\u00a0<a href=\"/free-to-use/\" style=\"color: #fff;text-decoration: underline\">content that is free to use and reuse <i class=\"icon icon-angle-double-right\"></i></a></p>\n",
#         "layout": "unaligned",
#         "results": [
#             {
#                 "alt": "Profile view of a woman walking a small dog briskly across an intersection with a car and traffic signal in the background. She is wearing a dress, heels, and a cloche-style hat.",
#                 "image": "/static/portals/free-to-use/public-domain/walking/walking-hiking-1.jpg",
#                 "link": "/resource/ppmsca.70409/",
#                 "title": "Woman walking a dog, New York City. Photo by Angelo Rizzuto, 1958."
#             },
#             {
#                 "alt": "Poster shows a woman walking vigorously on her own among trees and hills.",
#                 "image": "/static/portals/free-to-use/public-domain/walking/walking-hiking-2.jpg",
#                 "link": "/resource/cph.3f05232/",
#                 "title": "Hiking. By Shari Weisberg, 1930s.  WPA recreation project, Illinois."
#             },
#             {
#                 "alt": "A laughing toddler stands in a circular device on wheels that allows the child to walk across the floor.",
#                 "image": "/static/portals/free-to-use/public-domain/walking/walking-hiking-3.jpg",
#                 "link": "/resource/cph.3b38507/",
#                 "title": "\"Learning to walk.\" 1905.\n"
#             },
#             {
#                 "alt": "Very large crowd of women and men wearing racing numbers, running shorts, and sneakers as they sprint down the street.",
#                 "image": "/static/portals/free-to-use/public-domain/walking/walking-hiking-4.jpg",
#                 "link": "/resource/highsm.14430/",
#                 "title": "Race for the Cure on Pennsylvania Avenue, Washington, D.C. Photo by Carol M. Highsmith, 1990."
#             },
#             {
#                 "alt": "A man in a wheelchair rolls from the platform towards an open subway door.",
#                 "image": "/static/portals/free-to-use/public-domain/walking/walking-hiking-5.jpg",
#                 "link": "/item/2017652950/",
#                 "title": "Metro: subway facilities for handicapped, Washington, DC. By Thomas O'Halloran, 1977.\n"
#             },
#             {
#                 "alt": "Two people with their backs to the camera are walking down a road near a billboard that says \"Next time, try the train. Relax.\" \n",
#                 "image": "/static/portals/free-to-use/public-domain/walking/walking-hiking-6.jpg",
#                 "link": "/resource/fsa.8b31801/",
#                 "title": "Toward Los Angeles, California. By Dorothea Lange, 1937."
#             },
#             {
#                 "alt": "Vertical blue flag on a pole in the sidewalk with a white silhouette of a man in a hat striding along with a cane in one hand.",
#                 "image": "/static/portals/free-to-use/public-domain/walking/walking-hiking-7.jpg",
#                 "link": "/resource/highsm.67985/",
#                 "title": "Flag showing the silhouette of President Harry S. Truman walking with his cane marks a site along the Truman Historic Walking Trail in his hometown, Independence, Missouri. By Carol M. Highsmith, 2021."
#             },
#             {
#                 "alt": "A woman supports a young boy with braces on both legs by holding his crutches under his arms. The boy looks down at a picture labeled \"Puppies\" on the floor.\n",
#                 "image": "/static/portals/free-to-use/public-domain/walking/walking-hiking-8.jpg",
#                 "link": "/resource/fsa.8b07791/",
#                 "title": "A student nurse, acting as physical therapist, points to the picture book, thus encouraging this toddler to learn to use his crutches. By Fritz Henle, 1942."
#             },
#             {
#                 "alt": "Photo shows a group of Black people as they walk down the street. Includes women carry signs for equal rights, integrated schools, decent housing, and an end to bias.",
#                 "image": "/static/portals/free-to-use/public-domain/walking/walking-hiking-9.jpg",
#                 "link": "/resource/ppmsca.03128/",
#                 "title": "March on Washington for Jobs and Freedom, a civil rights demonstration in Washington, DC.  By Warren Leffler, 1963"
#             },
#             {
#                 "alt": "A line of Black men and women wearing \"Freedom Now\" shirts and a variety of shoes carry bags and backpacks as they walk in pairs down a street.\n",
#                 "image": "/static/portals/free-to-use/public-domain/walking/walking-hiking-10.jpg",
#                 "link": "/resource/cph.3c35795/",
#                 "title": "CORE members swing down Fort Hamilton Parkway, Brooklyn, toward 69th St. ferry on trek to Washington, DC. By O. Fernandez, 1963."
#             },
#             {
#                 "alt": "Two women in traditional clothing walk barefoot along a dirt road.",
#                 "image": "/static/portals/free-to-use/public-domain/walking/walking-hiking-11.jpg",
#                 "link": "/resource/wtc.4a02904/",
#                 "title": "Two women walking along a road in Sri Lanka.  By William Henry Jackson, 1895."
#             },
#             {
#                 "alt": "One man pauses while walking across the ice beside a line of six dogs who are pulling another man in a sled.",
#                 "image": "/static/portals/free-to-use/public-domain/walking/walking-hiking-12.jpg",
#                 "link": "/resource/cph.3f05804/",
#                 "title": "Nanai men with dog sled on Amur River, Russia. By William Henry Jackson, 1895."
#             },
#             {
#                 "alt": "The man wears a ragged shirt and looks at the camera while holding the hand of a young child wearing a dress and shawl. Both wear caps.",
#                 "image": "/static/portals/free-to-use/public-domain/walking/walking-hiking-13.jpg",
#                 "link": "/resource/ppmsca.51076/",
#                 "title": "Man carrying sticks and walking with little girl in field of wild flowers. Around 1900."
#             },
#             {
#                 "alt": "Several Black children walk by in pairs along a dirt road with trees in the background. Two are carrying jackets and sweaters in their arms.",
#                 "image": "/static/portals/free-to-use/public-domain/walking/walking-hiking-14.jpg",
#                 "link": "/resource/fsa.8d32642/",
#                 "title": "\"Bear Mountain, New York. Interracial activities at Camp Fern Rock, where children are aided by the Methodist Camp Service. Campers returning from a day's hike.\" By Gordon Parks, 1943.\n"
#             },
#             {
#                 "alt": "A young man stands on miniature, two-wheeled bicycle-like roller skates that are pedaled.",
#                 "image": "/static/portals/free-to-use/public-domain/walking/walking-hiking-15.jpg",
#                 "link": "/resource/ppmsca.31937/",
#                 "title": "Roller skating. By Bain News Service, 1910."
#             },
#             {
#                 "alt": "Women and men, mostly middle age, fill the sidewalk, moving in both directions, with stores in the background. A man at a mailbox is licking a stamp before mailing a letter.",
#                 "image": "/static/portals/free-to-use/public-domain/walking/walking-hiking-16.jpg",
#                 "link": "/resource/ppmsca.69658/",
#                 "title": "42nd St., New York City, telefoto from a bus. By Anthony Rizzuto, 1953."
#             },
#             {
#                 "alt": "A series of 12 consecutive images showing the motions of a man walking while taking a straw hat off his head.",
#                 "image": "/static/portals/free-to-use/public-domain/walking/walking-hiking-17.jpg",
#                 "link": "/resource/cph.3c03031/",
#                 "title": "Man walking with a hat. By Edweard Muybridge, 1887. Plate 44 in Animal Locomotion."
#             },
#             {
#                 "alt": "Several men in top hats use their feet striding along the ground to propel their bicycles along a roadway at a mile marker labeled \"London 2 Miles\".\n",
#                 "image": "/static/portals/free-to-use/public-domain/walking/walking-hiking-18.jpg",
#                 "link": "/resource/pga.07317/",
#                 "title": "The Hobby Horse, 1819. (Bicycles without pedals). London: Leadenhall Press, 1894.\n"
#             },
#             {
#                 "alt": "A young woman wearing a dress and a man in a suit are speeding along on bicycles with pedals on the front wheels",
#                 "image": "/static/portals/free-to-use/public-domain/walking/walking-hiking-19.jpg",
#                 "link": "/resource/afc1928004.afc1928004_081/",
#                 "title": "The Velocipede Belle Songster. New York, 1869. (American Folklife Center)"
#             },
#             {
#                 "alt": "A woman  sits in a chair inside a large bicycle wheel with two smaller wheels at the back on a country road.",
#                 "image": "/static/portals/free-to-use/public-domain/walking/walking-hiking-20.jpg",
#                 "link": "/resource/cph.3a09975/",
#                 "title": "View of Oldrieve's new tricycle, the New Iron Horse, with a lady inside, By Charles Oldreive, 1882."
#             },
#             {
#                 "alt": "A man wearing ragged clothes strides along while a dog runs happily alongside him.",
#                 "image": "/static/portals/free-to-use/public-domain/walking/walking-hiking-21.jpg",
#                 "link": "/resource/music.musdcmicon-0729/",
#                 "title": "Caricature of old man walking and playing flute. (Music Division)\n"
#             },
#             {
#                 "alt": "Two men support the poles in front of the covered chair while two other men support the poles behind the chair.",
#                 "image": "/static/portals/free-to-use/public-domain/walking/walking-hiking-22.jpg",
#                 "link": "/resource/wtc.4a03216/",
#                 "title": "Four men carrying sedan chair, China. By William Henry Jackson, 1895."
#             },
#             {
#                 "alt": "Row of men, shown in profile, walking across a snowy field or frozen body of water.",
#                 "image": "/static/portals/free-to-use/public-domain/walking/walking-hiking-23.jpg",
#                 "link": "/resource/cph.3a41358/",
#                 "title": "Six men walking on snowshoes. By Stoddard, around 1890."
#             },
#             {
#                 "alt": "A woman wearing a yellow coat pauses while walking dogs on a snow-covered slope with skiiers and trees in the background.",
#                 "image": "/static/portals/free-to-use/public-domain/walking/walking-hiking-24.jpg",
#                 "link": "/resource/tofr.34412/",
#                 "title": "Ann Bonfoey Taylor walking three West Highland White Terrier dogs, Vail, Colorado. By Toni Frissell, 1967."
#             },
#             {
#                 "alt": "Two men in army uniforms wear a long floating device on each foot while gliding upright across a river or lake. One man carries a rifle and the other man is pulling a soldier who lies flat across two of the floating devices.",
#                 "image": "/static/portals/free-to-use/public-domain/walking/walking-hiking-25.jpg",
#                 "link": "/resource/ppmsca.39660/",
#                 "title": "\"Walking on Water\" demonstration. By Warren Leffler, 1962.\n"
#             },
#             {
#                 "alt": "Women in long skirts and head scarves are in the foreground with men and boys wearing shorts and sneakers are in the background with a roller coaster in the distance.",
#                 "image": "/static/portals/free-to-use/public-domain/walking/walking-hiking-26.jpg",
#                 "link": "/resource/highsm.41914/",
#                 "title": "Patrons stroll among the rides at King's Island theme park in Mason, a suburb of Cincinnati, Ohio. By Carol M. Highsmith, 2016."
#             },
#             {
#                 "alt": "Smiling young woman is wearing a picture hat and a long red dress. She raises her slim skirt above her ankles while walking, which shows the bottom of her ruffled petticoat.",
#                 "image": "/static/portals/free-to-use/public-domain/walking/walking-hiking-27.jpg",
#                 "link": "/resource/ppmsca.59531/",
#                 "title": "\"Taking a stroll.\" By Hamilton King, 1907.\n"
#             },
#             {
#                 "alt": "Four men with leg or foot injuries use wooden crutches to participate in a race down a road with barrack-like buildings in the background.",
#                 "image": "/static/portals/free-to-use/public-domain/walking/walking-hiking-28.jpg",
#                 "link": "/resource/anrc.03662/",
#                 "title": "U.S. General Hospital No. 1. Crutch race for patients. By American Red Cross, 1919."
#             },
#             {
#                 "alt": "A one-legged soldier in uniform is supported by crutches attached to a belt. He is throwing a rock at a sign showing the face of the Kaiser.",
#                 "image": "/static/portals/free-to-use/public-domain/walking/walking-hiking-29.jpg",
#                 "link": "/resource/anrc.06234/",
#                 "title": "\"New legs for old. Tommy with new belt-crutch, can pelt the Kaiser to his heart's delight.\" By American Red Cross, 1917-1920.\n"
#             },
#             {
#                 "alt": "Man in uniform stands with crutches and stares into the camera. His right leg is amputated above the knee.",
#                 "image": "/static/portals/free-to-use/public-domain/walking/walking-hiking-30.jpg",
#                 "link": "/resource/ppmsca.75082/",
#                 "title": "Private Richard T. Gilbert of Co. D, 18th Georgia Infantry Regiment on crutches after losing his leg at the Battle of Gettysburg in 1863."
#             },
#             {
#                 "alt": "A man and woman wearing large backpacks and holding walking sticks pose with their dog along the wooded trail.",
#                 "image": "/static/portals/free-to-use/public-domain/walking/walking-hiking-31.jpg",
#                 "link": "/resource/highsm.13301/",
#                 "title": "Three expert hikers pose on the Appalachian Trail near Damascus, Virginia. Photo by Carol M. Highsmith, around 2000."
#             },
#             {
#                 "alt": "Brown metal sign shows two hikers in silhouette wearing backpacks and walking sticks.",
#                 "image": "/static/portals/free-to-use/public-domain/walking/walking-hiking-32.jpg",
#                 "link": "/resource/highsm.47345/",
#                 "title": "Crossing sign for the iconic Appalachian Trail, in this case a portion near Bartlett, New Hampshire. By Carol M. Highsmith, 2017."
#             },
#             {
#                 "alt": "A man carrying a bed roll over his shoulder walks along the side of a road. Other people in the background are also walking away from the camera.",
#                 "image": "/static/portals/free-to-use/public-domain/walking/walking-hiking-33.jpg",
#                 "link": "/resource/fsa.8b27246/",
#                 "title": "\"The trek of bums, tramps, single transients and undesirable indigents out of Los Angeles County because of police activity.\" California. By Dorothea Lange, 1936.\n"
#             },
#             {
#                 "alt": "Crowd of Black men, women, and children stands on the bridge. One woman holds a sign that reads \"National Voting Rights Museum. Celebrate the right to vote with annual bridge crossing jubilee.\"\n",
#                 "image": "/static/portals/free-to-use/public-domain/walking/walking-hiking-34.jpg",
#                 "link": "/resource/highsm.05942/",
#                 "title": "45th Anniversary of the Civil Rights March from Selma, Alabama to Montgomery, Alabama. Photo by Carol M. Highsmith, 2010."
#             },
#             {
#                 "alt": "A crowd of women wearing large hats and long dresses and men wearing suits and straw boaters stroll together.",
#                 "image": "/static/portals/free-to-use/public-domain/walking/walking-hiking-35.jpg",
#                 "link": "/resource/pcrd.1d04598/",
#                 "title": "\"On the board walk, Long Beach, N.Y.\" By Ambrose Fowler, 1912.\n"
#             },
#             {
#                 "alt": "Long line of men walking up a snow-covered, steep hill carrying heavy packs.  Seen from behind.",
#                 "image": "/static/portals/free-to-use/public-domain/walking/walking-hiking-36.jpg",
#                 "link": "/resource/stereo.1s49572/",
#                 "title": "\"Klondikers starting up \"The Golden Stair,\" Chilkoot Pass, Alaska.\" By Keystone View Co., 1898.\n"
#             },
#             {
#                 "alt": "The woman pushing the stroller wears knee-length shorts, and the other woman is wearing a knee-length dress.",
#                 "image": "/static/portals/free-to-use/public-domain/walking/walking-hiking-37.jpg",
#                 "link": "/resource/ppmsca.70655/",
#                 "title": "Back view of two women walking on sidewalk while toddler in stroller looks back towards the photographer. By Anthony Rizzuto, 1959"
#             },
#             {
#                 "alt": "Poster showing a man falling to the ground after being struck by a car. A policeman runs towards the man.",
#                 "image": "/static/portals/free-to-use/public-domain/walking/walking-hiking-38.jpg",
#                 "link": "/resource/cph.3b49000/",
#                 "title": "\"Don't jay walk. Watch your step.\" By Isadore Posoff, 1936 or 1937.\n"
#             },
#             {
#                 "alt": "Three white men and a Black man are running fast while a crowd looks on.",
#                 "image": "/static/portals/free-to-use/public-domain/walking/walking-hiking-39.jpg",
#                 "link": "/resource/cph.3b34759/",
#                 "title": "\"New York City. The fifth contest for the long-distance pedestrian championship of the world, at the Madison Square Garden. A spurt for the lead.\" 1879.\n"
#             },
#             {
#                 "alt": "Two young children in traditional Chinese clothing stand in the middle of the sidewalk while a man walks another child up the hill towards them.",
#                 "image": "/static/portals/free-to-use/public-domain/walking/walking-hiking-40.jpg",
#                 "link": "/resource/agc.7a08994/",
#                 "title": "Returning home, Chinatown, San Francisco. By Arnold Genthe, 1896-1906.\n"
#             },
#             {
#                 "alt": "Cover illustration shows two men in athletic outfits  striding along a road while onlookers cheer them on.",
#                 "image": "/static/portals/free-to-use/public-domain/walking/walking-hiking-41.jpg",
#                 "link": "/resource/gdcmassbookdig.youngpedestrianc00unse/?sp=1",
#                 "title": "\"The Young Pedestrian. Containing clear instructions how to train and prepare for long walks, coupled to which is a record of all the great pedestrian contests up to date.\" New York, 1882. (General Collections)\n"
#             },
#             {
#                 "alt": "Crowds line both sides of the street to watch men running by in athletic outfits with individual ID numbers.",
#                 "image": "/static/portals/free-to-use/public-domain/walking/walking-hiking-42.jpg",
#                 "link": "/resource/cph.3c11275/",
#                 "title": "\"Start, Brooklyn marathon.\" By Bain News Service, 1909.\n"
#             },
#             {
#                 "alt": "Poster shows the profile of a man walking sedately in a park-like setting with large trees behind him and bushes in the foreground.",
#                 "image": "/static/portals/free-to-use/public-domain/walking/walking-hiking-43.jpg",
#                 "link": "/resource/cph.3b48760/",
#                 "title": "Hiking. By Beard, 1939. WPA recreation project, Illinois."
#             }
#         ],
#         "title": "Free to Use and Reuse: Walking"
#     },
#     "meta": {
#         "description": "The world's largest library. View historic photos, maps, books and more. Contact experts for help with research. Plan a visit. Home of U.S. Copyright Office.",
#         "title": "Home"
#     },
#     "options": {
#         "access_group": [
#             ""
#         ],
#         "access_group_raw": "",
#         "all": null,
#         "api_version": "1",
#         "app_context": null,
#         "application_version": "$Revision$",
#         "attribute": null,
#         "attribute!": null,
#         "attribute_map": null,
#         "cache_tags": [],
#         "callback": null,
#         "clip": null,
#         "clip_image_width": null,
#         "clip_rotation": null,
#         "content_filter": null,
#         "content_replacement": "",
#         "count": null,
#         "dates": null,
#         "default_count": 25,
#         "delimiter": null,
#         "digital_id": null,
#         "display_level": null,
#         "distance": null,
#         "downloadOption": null,
#         "duration": 0.0011301040649414062,
#         "embed": [],
#         "embed!": [],
#         "excludeTerms": null,
#         "facetLimits": "",
#         "facetPrefix": null,
#         "facet_count": null,
#         "facet_style": null,
#         "field": null,
#         "format": "json",
#         "host": "www.loc.gov",
#         "ical": false,
#         "id": null,
#         "iiif": false,
#         "index": null,
#         "inputEncoding": "UTF-8",
#         "is_portal": null,
#         "item": null,
#         "items": null,
#         "keys": null,
#         "language": null,
#         "latlong": null,
#         "method": "GET",
#         "newSearch": null,
#         "new_clip_url": false,
#         "onsite": false,
#         "operator": null,
#         "outputEncoding": "UTF-8",
#         "page_campaigns": [],
#         "path_info": "/",
#         "port": "443",
#         "portal": "home",
#         "proxypath": null,
#         "query_string": "fo=json&q=lincoln",
#         "redirect_proxy": false,
#         "redirect_to_item": null,
#         "referer": "",
#         "region": "",
#         "release_id": 123456789,
#         "request_host": "www.loc.gov",
#         "request_params": {
#             "fo": [
#                 "json"
#             ],
#             "q": "lincoln"
#         },
#         "request_url": "https://www.loc.gov/?fo=json&q=lincoln",
#         "resource": "",
#         "resource_sequence": null,
#         "scheme": "https",
#         "searchIn": null,
#         "searchTerms": "lincoln",
#         "segments": null,
#         "site_id": null,
#         "site_type": null,
#         "solrQuery": "",
#         "sortBy": null,
#         "sortOrder": null,
#         "startPage": null,
#         "style": null,
#         "suggested": null,
#         "target": null,
#         "template": "home/home",
#         "timestamp": 1729645525.69096,
#         "tz_aware": null,
#         "unionFacets": "",
#         "webcast_permalink": null
#     },
#     "portal": false,
#     "programs": {
#         "items": [
#             {
#                 "link": "https://catalog.loc.gov/",
#                 "title": "Library Catalog"
#             },
#             {
#                 "link": "/collections/",
#                 "title": "Digital Collections"
#             },
#             {
#                 "link": "https://research-appointments.loc.gov/",
#                 "title": "Researchers"
#             },
#             {
#                 "link": "/visit/",
#                 "title": "Visitors"
#             },
#             {
#                 "link": "/teachers/",
#                 "title": "Teachers"
#             },
#             {
#                 "link": "https://blogs.loc.gov/",
#                 "title": "Blogs"
#             },
#             {
#                 "link": "https://copyright.gov/",
#                 "title": "U.S. Copyright Office"
#             },
#             {
#                 "link": "/services-and-programs/",
#                 "title": "More..."
#             }
#         ],
#         "title": "Programs, services"
#     },
#     "timestamp": 1729645525692,
#     "top_searches": [
#         {
#             "label": "Civil War",
#             "search": "Civil War"
#         },
#         {
#             "label": "Newspapers",
#             "search": "newspapers"
#         },
#         {
#             "label": "War of 1812",
#             "search": "war of 1812"
#         },
#         {
#             "label": "Slavery",
#             "search": "slavery"
#         },
#         {
#             "label": "American Revolution",
#             "search": "american revolution"
#         },
#         {
#             "label": "Child Labor",
#             "search": "child labor"
#         }
#     ],
#     "trending_content": [
#         {
#             "image": "/static/home/images/trending/blogs/2024-raven_480x320.jpg",
#             "link": "https://blogs.loc.gov/loc/2024/10/the-season-of-edgar-allan-poe-autumn-halloween-and-the-falling-darkness/",
#             "portal": "Blog",
#             "title": "The Season of Edgar Allan Poe: Halloween and the Falling Darkness"
#         },
#         {
#             "image": "/static/home/images/trending/lcm/2024sepoct_480x320.jpg",
#             "link": "/lcm/pdf/LCM_2024_0910.pdf",
#             "portal": "Magazine",
#             "title": "Building America: Chronicling the History of U.S. Architecture"
#         },
#         {
#             "image": "/static/home/images/trending/evergreen/news2022_480x320.jpg",
#             "link": "https://newsroom.loc.gov",
#             "portal": "News",
#             "title": "Get the Latest News from the Library of Congress"
#         },
#         {
#             "image": "/static/home/images/trending/evergreen/events2022_480x320.jpg",
#             "link": "/events/",
#             "portal": "Events",
#             "title": "Our Calendar of Upcoming Events, In-Person & Virtual"
#         },
#         {
#             "image": "/static/home/images/trending/exhibits/exhibitions-evergreen-suffrage-48079406641_69c1146579_k.jpg",
#             "link": "/exhibits/",
#             "portal": "Exhibitions",
#             "title": "Explore Library Exhibitions in Person & Online"
#         },
#         {
#             "image": "/static/home/images/trending/evergreen/2024-volunteer_480x320.jpg",
#             "link": "/visit/volunteer",
#             "portal": "Volunteer",
#             "title": "Apply Today to Volunteer at the Library in Washington D.C."
#         }
#     ],
#     "type": "orientation-portal",
#     "your_library": {
#         "description": "Use the largest library in the world online or in person! <a href=\"/about/\">More about the Library</a>.",
#         "items": [
#             {
#                 "image": "/static/home/images/your-library/01-PlanYourVisit.jpg",
#                 "link": "/visit/",
#                 "title": "Plan Your Visit"
#             },
#             {
#                 "image": "/static/home/images/your-library/02-ResearchCenter.jpg",
#                 "link": "/rr/",
#                 "title": "Research Centers"
#             },
#             {
#                 "image": "/static/home/images/your-library/03-AskLibrarian.jpg",
#                 "link": "https://ask.loc.gov/",
#                 "title": "Ask a Librarian"
#             }
#         ],
#         "link": "",
#         "link_text": "",
#         "title": "Your Library"
#     }
# }
